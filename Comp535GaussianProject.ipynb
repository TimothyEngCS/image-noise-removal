# %%
# !git clone https://github.com/TimothyEngCS/image-noise-removal.git
# Out:
# Cloning into 'image-noise-removal'...
# remote: Enumerating objects: 17, done.
# remote: Counting objects: 100% (17/17), done.
# remote: Compressing objects: 100% (14/14), done.
# remote: Total 17 (delta 2), reused 8 (delta 1), pack-reused 0 (from 0)
# Unpacking objects: 100% (17/17), 1.27 MiB | 2.88 MiB/s, done.

# %%
# %cd image-noise-removal
# Out:
# /home/john/image-noise-removal
# /home/john/anaconda3/envs/COMP535/lib/python3.12/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
# !git checkout -b john-vega-gaussian
# Out:
# Switched to a new branch 'john-vega-gaussian'

# %%
# !pip install opencv-python
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 MB 17.6 MB/s eta 0:00:000:00:010:00:01:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.0/16.0 MB 18.5 MB/s eta 0:00:0031m19.1 MB/s eta 0:00:01
# ...

# %%
# !pip install matplotlib
# Out:
# ...
#   Using cached matplotlib-3.9.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached pillow-10.4.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (9.2 kB)
# ...
# Using cached matplotlib-3.9.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.3 MB)
# ...
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 10.8 MB/s eta 0:00:00 MB/s eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 14.0 MB/s eta 0:00:00
# Using cached pillow-10.4.0-cp312-cp312-manylinux_2_28_x86_64.whl (4.5 MB)
# ...

# %%
import cv2 as cv
import os
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

def gaussian_kernel(size, sigma):
    kernel = cv.getGaussianKernel(size, sigma)
    kernel = np.outer(kernel, kernel)
    return kernel

def gaussian_filter(size, sigma):
    root = os.getcwd()
    imgPath = os.path.join(root, 'archive//Truck//Datacluster Truck (1).jpg')
    img = cv.imread(imgPath)

    fig = plt.figure()
    plt.subplot(121)
    kernel = gaussian_kernel(size, sigma)
    plt.imshow(kernel)

    ax = fig.add_subplot(1,2,2, projection="3d")
    x = np.arange(0,size,1)
    y = np.arange(0,size,1)
    X,Y = np.meshgrid(x,y)
    ax.plot_surface(X,Y,kernel,cmap='viridis')


    plt.show()

if __name__ == '__main__':
    gaussian_filter(32, 8)

# %%
cp home/Comp535GaussianProject.ipynb /home/john/image-noise-removal
# Out:
# cp: cannot stat 'home/Comp535GaussianProject.ipynb': No such file or directory

# %%
# !git add Comp535GaussianProject.ipynb
# Out:
# fatal: pathspec 'Comp535GaussianProject.ipynb' did not match any files
